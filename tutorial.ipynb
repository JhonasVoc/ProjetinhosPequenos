# %% [markdown]
# ## Print

# %%
import numpy as np
import random

# %%
print("Pizza it's nice")
# Out:
# Pizza it's nice

# %%
full_name = "Josh mcnell forms"
print(full_name)
print(f"{full_name}")
# Out:
# Josh mcnell forms
# Josh mcnell forms

# %%
age = 26
print(f"You are {age} years old")
# Out:
# You are 26 years old

# %%
balance = 345.55
print(f"Your balance is {balance} dollars")
# Out:
# Your balance is 345.55 dollars

# %%
def prints(*args):
    print(*args)

# %%
prints(1,2,3,4,5)
# Out:
# 1 2 3 4 5

# %%
def soma(*args):
    soma = 0
    for i in args:
        soma += i
    
    return soma

# %%
soma(2,2,3,2,2,2,2)
# Out:
# 2

# %%
sum1 = soma(2,2,3,2,2,2,2)
print(sum1)
# Out:
# 15

# %%
import json

# %%
my_dict = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

# %%
with open("data.json", "w") as file:
    json.dump(my_dict, file,indent=4)

# %%
dicas = 5
list2 = list(range(1,dicas +1))
list2
# Out:
# [1, 2, 3, 4, 5]
